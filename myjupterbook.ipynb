# %%
# !pip install seaborn

# %%
import seaborn as sn

# %%
import pandas as pd 
import numpy as np

#data visualization libraries
import matplotlib_inline as map

# %%
pd.set_option('display.max_rows', None)

# %%
#Choose the coloumns you want from large dataframe
df = pd.read_csv('train_data.csv', 
                 usecols=['Id','MSZoning', 'LotArea',
                          'Street','Utilities','Condition1',  'OverallQual', 
           'OverallCond', 'YearBuilt',  'HeatingQC',
           'CentralAir', 'KitchenQual','GarageCond',
           'PoolArea', 'SalePrice'])

# %%
df
# Out:
#         Id MSZoning  LotArea Street Utilities Condition1  OverallQual  \
# 0        1       RL     8450   Pave    AllPub       Norm            7
# 1        2       RL     9600   Pave    AllPub      Feedr            6
# 2        3       RL    11250   Pave    AllPub       Norm            7
# 3        4       RL     9550   Pave    AllPub       Norm            7
# 4        5       RL    14260   Pave    AllPub       Norm            8
# 5        6       RL    14115   Pave    AllPub       Norm            5
# 6        7       RL    10084   Pave    AllPub       Norm            8
# 7        8       RL    10382   Pave    AllPub       PosN            7
# 8        9       RM     6120   Pave    AllPub     Artery            7
# 9       10       RL     7420   Pave    AllPub     Artery            5
# 10      11       RL    11200   Pave    AllPub       Norm            5
# 11      12       RL    11924   Pave    AllPub       Norm            9
# ...

# %%
df2 = df[['YearBuilt','HeatingQC']]

# %%
df2
# Out:
#       YearBuilt HeatingQC
# 0          2003        Ex
# 1          1976        Ex
# 2          2001        Ex
# 3          1915        Gd
# 4          2000        Ex
# 5          1993        Ex
# 6          2004        Ex
# 7          1973        Ex
# 8          1931        Gd
# 9          1939        Ex
# 10         1965        Ex
# 11         2005        Ex
# 12         1962        TA
# 13         2006        Ex
# 14         1960        TA
# 15         1929        Ex
# 16         1970        Ex
# 17         1967        TA
# 18         2004        Ex
# 19         1958        TA
# 20         2005        Ex
# 21         1930        Ex
# 22         2002        Ex
# 23         1976        TA
# 24         1968        Ex
# 25         2007        Ex
# 26         1951        TA
# 27         2007        Ex
# 28         1957        TA
# 29         1927        Fa
# 30         1920        TA
# 31         1966        Gd
# 32         2007        Ex
# 33         1959        Gd
# ...

# %%
new

# %%
#print all coloumns in the dataframe
df.columns
# Out:
# Index(['Id', 'MSZoning', 'LotArea', 'Street', 'Utilities', 'Condition1',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'HeatingQC', 'CentralAir',
#        'KitchenQual', 'GarageCond', 'PoolArea', 'SalePrice'],
#       dtype='object')

# %%
#to select one or more columns
df_streets = df[['Street', 'OverallQual', 'OverallCond','SalePrice']]

# %%
df_streets
# Out:
#      Street  OverallQual  OverallCond  SalePrice
# 0      Pave            7            5     208500
# 1      Pave            6            8     181500
# 2      Pave            7            5     223500
# 3      Pave            7            5     140000
# 4      Pave            8            5     250000
# ...     ...          ...          ...        ...
# 1455   Pave            6            5     175000
# 1456   Pave            6            6     210000
# 1457   Pave            7            9     266500
# 1458   Pave            5            6     142125
# 1459   Pave            5            6     147500
#
# [1460 rows x 4 columns]

# %%
df_streets.describe().round(2)
# Out:
#        OverallQual  OverallCond  SalePrice
# count      1460.00      1460.00     1460.0
# mean          6.10         5.58   180921.2
# std           1.38         1.11    79442.5
# min           1.00         1.00    34900.0
# 25%           5.00         5.00   129975.0
# 50%           6.00         5.00   163000.0
# 75%           7.00         6.00   214000.0
# max          10.00         9.00   755000.0

# %%
df.loc[[0,1,] ,'Street']
# Out:
# 0    Pave
# 1    Pave
# Name: Street, dtype: object

# %%
df_streets['OverallQual']
# Out:
# 0       7
# 1       6
# 2       7
# 3       7
# 4       8
#        ..
# 1455    6
# 1456    6
# 1457    7
# 1458    5
# 1459    5
# Name: OverallQual, Length: 1460, dtype: int64

# %%
df_streets['OverallQual'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0       7
# 1       6
# 2       7
# 3       7
# 4       8
#        ..
# 1455    6
# 1456    6
# 1457    7
# 1458    5
# 1459    5
# Name: OverallQual, Length: 1460, dtype: int64>

# %%
#scatter plot shows the relationship between two quantitative
#variables measured for the same individuals.
#hue is used to add categorical data
sn.scatterplot(
    data=df,
    x='HouseStyle',
    y='SalePrice',
    hue='YearBuilt',
    palette='icefire',
    size='YearBuilt'
)
# Out:
# <AxesSubplot:xlabel='HouseStyle', ylabel='SalePrice'>

# %% [markdown]
# # interpration : houses built in 2020 have overall good condition and quality
# #its not the best data but good for begginer scatter understanding

# %%
#this are the coeffiecients results for the variables
regression = np.polyfit(df['OverallQual'], df['OverallCond'],deg = 1)
regression
# Out:
# array([-0.07397144,  6.0265176 ])

# %%
#seaborn palettes
#husl,Set2, Paired, rocket,mako,flare, crest,magma,viridis,icefire

# %%
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df['LotArea'].value_counts().sort_index()
# Out:
# 1300      1
# 1477      1
# 1491      1
# 1526      1
# 1533      2
#          ..
# 70761     1
# 115149    1
# 159000    1
# 164660    1
# 215245    1
# Name: LotArea, Length: 1073, dtype: int64

# %%
#filtering rows named pave
filt = (df['LotArea']>10000)

# %%
df[filt]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# 5        6          50       RL         85.0    14115   Pave   NaN      IR1
# 6        7          20       RL         75.0    10084   Pave   NaN      Reg
# 7        8          60       RL          NaN    10382   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1442  1443          60       FV         85.0    11003   Pave   NaN      Reg
# 1446  1447          20       RL          NaN    26142   Pave   NaN      IR1
# 1448  1449          50       RL         70.0    11767   Pave   NaN      Reg
# 1453  1454          20       RL         90.0    17217   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
#
# ...

# %%
# Another way to filter rows is using loc
df.loc[filt].head(5)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
# filter row named paved coloumn Utilities
df.loc[filt,'Utilities'].head(5)
# Out:
# 0    AllPub
# 1    AllPub
# 2    AllPub
# 3    AllPub
# 4    AllPub
# Name: Utilities, dtype: object

# %%
# and (&), and or (|) can be used to filter data as well
filt = (df['Street']=='Pave') & (df['Utilities']=='AllPub').head(5)
